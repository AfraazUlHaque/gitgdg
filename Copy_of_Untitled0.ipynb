# %% [markdown]
# <a href="https://colab.research.google.com/github/AfraazUlHaque/gitgdg/blob/main/Copy_of_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df = pd.read_csv('/content/drive/MyDrive/CNB/googleplaystore.csv')

# %%
df.info()

# %%
df.sample(4)

# %%
example_size = "19M"
numeric_value = float(example_size.replace('M', ''))
print(f"Original: {example_size}, Converted: {numeric_value}")

# %% [markdown]
# This same logic is applied by the `convert_size_to_mb` function to the `Size` column in your DataFrame, creating the `size_mb` column.

# %%
print(df['Price'].unique())

# %%
import numpy as np

# Function to convert size string to MB
def convert_size_to_mb(size):
    if isinstance(size, str):
        if 'M' in size:
            return float(size.replace('M', ''))
        elif 'k' in size:
            return float(size.replace('k', '')) / 1024
        elif 'Varies with device' in size:
            return np.nan
    return np.nan # Default for any other unexpected format or non-string types

# Apply the function to the 'Size' column to create 'size_mb'
df['size_mb'] = df['Size'].apply(convert_size_to_mb)

# %%
df.describe()

# %%
df['Price'].nunique()

# %%
df['Price'] = df['Price'].replace(r'\$', '', regex=True)
df['Price'] = df['Price'].replace('Everyone', np.nan)
df['Price'] = df['Price'].astype(float)

print("Price column converted to numeric type.")
display(df[['App', 'Price']].head())

# %%
df['Price'].isnull().sum()

# %%
df.info()

# %%
df.shape

# %%
df.columns

# %%
# !pip install ydata_profiling
from ydata_profiling import ProfileReport
profile = ProfileReport(df, title="Pandas Profiling Report" , explorative=True)
profile

# %%
profile.to_file("rep.html")
